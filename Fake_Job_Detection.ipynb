# %% [markdown]
# <a href="https://colab.research.google.com/github/NurIzzati11/Fake-Job-Detection-DS-Project-/blob/main/Fake_Job_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #FAKE JOB DETECTION
# -------------------
#
# ### **Progress Report**
#
# Date: 20/11/2022
#
#
# *   Downloaded dataset from Kaggle. [Source](https://www.kaggle.com/datasets/shivamb/real-or-fake-fake-jobposting-prediction/code)
#
#
# ```
# About the dataset: Contains 18K job descriptions out of which about 800 are fake. The data consists of both textual information
# and meta-information about the jobs. Data taken from The University of the Aegean | Laboratory of Information & Communication Systems
# Security http://emscad.samos.aegean.gr/
# ```
#
# *   Dataset is foudn to be imbalanced. Fake job posts are extremely lower than true job posts.
#
# ` | Legitimate = 95.16% | Fraudulent = 4.84% |`
#
#
# *   Read a paper that researched how to deal with this imbalance of dataset. (Link: [Source](https://dl.acm.org/doi/pdf/10.1145/3507524.3507537))
#
# *   Still contemplating if I should test out all the algorithms listed in the above paper or go with the top 3 algorithms with the best performance.
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## Handling Imbalanced Dataset
# -----------------------------------
#
# From the table above, case 9 that uses the hybrid of random over-sampling and under-sampling to handle the imbalanced dataset yields the highest overall score for all quantifiers.
#
# - Information on different kinds of ways to handle imbalanced datasets: [Link](https://www.analyticsvidhya.com/blog/2017/03/imbalanced-data-classification/)
#
#
# - Random over-samping & Under-sampling tutorial:
#   1. [Machine Learning Mastery](https://machinelearningmastery.com/random-oversampling-and-undersampling-for-imbalanced-classification/)
#   2. [Kaggle Notebook](https://www.kaggle.com/code/residentmario/undersampling-and-oversampling-imbalanced-data/notebook)
#
# - Bagging/Random Forest/Easy Ensemble
#   1. [Machine Learning Master](https://machinelearningmastery.com/bagging-and-random-forest-for-imbalanced-classification/#:~:text=Easy%20Ensemble-,Bagging%20for%20Imbalanced%20Classification,examples%20in%20the%20training%20dataset.) - contains bangging, easy ensemble and random forest for imbalanced dataset

# %% [markdown]
# ## Planning & Strategy
# ------------
# Date: 11/12/2022

# %% [markdown]
# ![Capture.PNG](data:image/png;base64,...)

# %% [markdown]
# ## Importing Libaries & Tools
# --------------

# %%
import pandas as pd

# %% [markdown]
# ## Dataset Insertion
# --------------

# %%
df=pd.read_csv("/fake_job_postings.csv")

# %%
df.head()
# Out:
#    job_id                                      title            location  \
# 0       1                           Marketing Intern    US, NY, New York
# 1       2  Customer Service - Cloud Video Production      NZ, , Auckland
# 2       3    Commissioning Machinery Assistant (CMA)       US, IA, Wever
# 3       4          Account Executive - Washington DC  US, DC, Washington
# 4       5                        Bill Review Manager  US, FL, Fort Worth
#
#   department salary_range                                    company_profile  \
# 0  Marketing          NaN  We're Food52, and we've created a groundbreaki...
# 1    Success          NaN  90 Seconds, the worlds Cloud Video Production ...
# 2        NaN          NaN  Valor Services provides Workforce Solutions th...
# 3      Sales          NaN  Our passion for improving quality of life thro...
# 4        NaN          NaN  SpotSource Solutions LLC is a Global Human Cap...
#
#                                          description  \
# ...

# %% [markdown]
# ## Dataset Preparation (cleaning, tidying, etc)
# --------------
#
# *in progress*

# %% [markdown]
# ## Exploratory Data Analysis
# -----------------------------
#
# *in progess*

# %% [markdown]
# ## Analysis / Modelling
# -----------------------
#
# *in progress*
#
# CODE STARTS HERE

# %% [markdown]
# CODE ENDS HERE

# %% [markdown]
# ## Evaluation & Interpretation
# -----------------------
#
# *in progress*
#
# CODE STARTS HERE

# %% [markdown]
# CODE ENDS HERE

# %% [markdown]
# ## Deployment (Streamlit)
# -----------------------
#
# *in progress*
#
# CODE STARTS HERE

# %% [markdown]
# CODE ENDS HERE

# %% [markdown]
# REPORT LINK: [Insert link]
